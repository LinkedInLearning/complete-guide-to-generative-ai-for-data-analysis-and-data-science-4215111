# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a directed graph
G = nx.DiGraph()

# List of realistic usernames
usernames = [
    "alice123", "bob_smith", "charlie_brown", "dave01", "eve_89", "frank_the_tank",
    "grace_hopper", "hank_the_dog", "ian_fleming", "jane_doe", "karen_miller",
    "leo_lion", "mike_tyson", "nina_ninja", "oliver_twist", "peter_parker",
    "queen_bee", "robin_hood", "steve_jobs", "tina_turner", "uma_thurman",
    "viktor_k", "wally_world", "xena_warrior", "yara_gray", "zane_zebra",
    "abby_adams", "ben_10", "chloe_clark", "dan_dare", "ellen_ellen", "fred_flint",
    "gina_george", "hugo_boss", "ivy_ivy", "jack_jill", "ken_kenny",
    "lisa_love", "mark_marky", "nate_nash", "olivia_olive", "paulie_pie",
    "quincy_quinn", "rose_rose", "sammy_sam", "terry_terry", "ursula_u",
    "victor_val", "winnie_pooh"
]

# List of edges (follows relationships)
edges = [
    ("alice123", "bob_smith"), ("alice123", "charlie_brown"), ("bob_smith", "dave01"),
    ("bob_smith", "eve_89"), ("charlie_brown", "frank_the_tank"), ("charlie_brown", "grace_hopper"),
    ("dave01", "hank_the_dog"), ("dave01", "ian_fleming"), ("eve_89", "jane_doe"),
    ("eve_89", "karen_miller"), ("frank_the_tank", "leo_lion"), ("frank_the_tank", "mike_tyson"),
    ("grace_hopper", "nina_ninja"), ("grace_hopper", "oliver_twist"), ("hank_the_dog", "peter_parker"),
    ("hank_the_dog", "queen_bee"), ("ian_fleming", "robin_hood"), ("ian_fleming", "steve_jobs"),
    ("jane_doe", "tina_turner"), ("jane_doe", "uma_thurman"), ("karen_miller", "viktor_k"),
    ("karen_miller", "wally_world"), ("leo_lion", "xena_warrior"), ("leo_lion", "yara_gray"),
    ("mike_tyson", "zane_zebra"), ("mike_tyson", "abby_adams"), ("nina_ninja", "ben_10"),
    ("nina_ninja", "chloe_clark"), ("oliver_twist", "dan_dare"), ("oliver_twist", "ellen_ellen"),
    ("peter_parker", "fred_flint"), ("peter_parker", "gina_george"), ("queen_bee", "hugo_boss"),
    ("queen_bee", "ivy_ivy"), ("robin_hood", "jack_jill"), ("robin_hood", "ken_kenny"),
    ("steve_jobs", "lisa_love"), ("steve_jobs", "mark_marky"), ("tina_turner", "nate_nash"),
    ("tina_turner", "olivia_olive"), ("uma_thurman", "paulie_pie"), ("uma_thurman", "quincy_quinn"),
    ("viktor_k", "rose_rose"), ("viktor_k", "sammy_sam"), ("wally_world", "terry_terry"),
    ("wally_world", "ursula_u"), ("xena_warrior", "victor_val"), ("xena_warrior", "winnie_pooh"),
    ("yara_gray", "alice123"), ("yara_gray", "bob_smith"), ("zane_zebra", "charlie_brown"),
    ("zane_zebra", "dave01"), ("abby_adams", "eve_89"), ("abby_adams", "frank_the_tank"),
    ("ben_10", "grace_hopper"), ("ben_10", "hank_the_dog"), ("chloe_clark", "ian_fleming"),
    ("chloe_clark", "jane_doe"), ("dan_dare", "karen_miller"), ("dan_dare", "leo_lion"),
    ("ellen_ellen", "mike_tyson"), ("ellen_ellen", "nina_ninja"), ("fred_flint", "oliver_twist"),
    ("fred_flint", "peter_parker"), ("gina_george", "queen_bee"), ("gina_george", "robin_hood"),
    ("hugo_boss", "steve_jobs"), ("hugo_boss", "tina_turner"), ("ivy_ivy", "uma_thurman"),
    ("ivy_ivy", "viktor_k"), ("jack_jill", "wally_world"), ("jack_jill", "xena_warrior"),
    ("ken_kenny", "yara_gray"), ("ken_kenny", "zane_zebra"), ("lisa_love", "abby_adams"),
    ("lisa_love", "ben_10"), ("mark_marky", "chloe_clark"), ("mark_marky", "dan_dare"),
    ("nate_nash", "ellen_ellen"), ("nate_nash", "fred_flint"), ("olivia_olive", "gina_george"),
    ("olivia_olive", "hugo_boss"), ("paulie_pie", "ivy_ivy"), ("paulie_pie", "jack_jill"),
    ("quincy_quinn", "ken_kenny"), ("quincy_quinn", "lisa_love"), ("rose_rose", "mark_marky"),
    ("rose_rose", "nate_nash"), ("sammy_sam", "olivia_olive"), ("sammy_sam", "paulie_pie"),
    ("terry_terry", "quincy_quinn"), ("terry_terry", "rose_rose"), ("ursula_u", "sammy_sam"),
    ("ursula_u", "terry_terry"), ("victor_val", "ursula_u"), ("victor_val", "victor_val"),
    ("winnie_pooh", "winnie_pooh"), ("winnie_pooh", "alice123"), ("bob_smith", "charlie_brown")
]

# Add edges to the graph
G.add_edges_from(edges)

# Draw the graph
plt.figure(figsize=(12, 12))
pos = nx.spring_layout(G, seed=12)
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", edge_color="gray")
plt.title("Social Network Graph")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a directed graph
G = nx.DiGraph()

# List of realistic usernames
usernames = [
    "alice123", "bob_smith", "charlie_brown", "dave01", "eve_89", "frank_the_tank",
    "grace_hopper", "hank_the_dog", "ian_fleming", "jane_doe", "karen_miller",
    "leo_lion", "mike_tyson", "nina_ninja", "oliver_twist", "peter_parker",
    "queen_bee", "robin_hood", "steve_jobs", "tina_turner", "uma_thurman",
    "viktor_k", "wally_world", "xena_warrior", "yara_gray", "zane_zebra",
    "abby_adams", "ben_10", "chloe_clark", "dan_dare", "ellen_ellen", "fred_flint",
    "gina_george", "hugo_boss", "ivy_ivy", "jack_jill", "ken_kenny",
    "lisa_love", "mark_marky", "nate_nash", "olivia_olive", "paulie_pie",
    "quincy_quinn", "rose_rose", "sammy_sam", "terry_terry", "ursula_u",
    "victor_val", "winnie_pooh"
]

# List of edges (follows relationships)
edges = [
    ("alice123", "bob_smith"), ("alice123", "charlie_brown"), ("bob_smith", "dave01"),
    ("bob_smith", "eve_89"), ("charlie_brown", "frank_the_tank"), ("charlie_brown", "grace_hopper"),
    ("dave01", "hank_the_dog"), ("dave01", "ian_fleming"), ("eve_89", "jane_doe"),
    ("eve_89", "karen_miller"), ("frank_the_tank", "leo_lion"), ("frank_the_tank", "mike_tyson"),
    ("grace_hopper", "nina_ninja"), ("grace_hopper", "oliver_twist"), ("hank_the_dog", "peter_parker"),
    ("hank_the_dog", "queen_bee"), ("ian_fleming", "robin_hood"), ("ian_fleming", "steve_jobs"),
    ("jane_doe", "tina_turner"), ("jane_doe", "uma_thurman"), ("karen_miller", "viktor_k"),
    ("karen_miller", "wally_world"), ("leo_lion", "xena_warrior"), ("leo_lion", "yara_gray"),
    ("mike_tyson", "zane_zebra"), ("mike_tyson", "abby_adams"), ("nina_ninja", "ben_10"),
    ("nina_ninja", "chloe_clark"), ("oliver_twist", "dan_dare"), ("oliver_twist", "ellen_ellen"),
    ("peter_parker", "fred_flint"), ("peter_parker", "gina_george"), ("queen_bee", "hugo_boss"),
    ("queen_bee", "ivy_ivy"), ("robin_hood", "jack_jill"), ("robin_hood", "ken_kenny"),
    ("steve_jobs", "lisa_love"), ("steve_jobs", "mark_marky"), ("tina_turner", "nate_nash"),
    ("tina_turner", "olivia_olive"), ("uma_thurman", "paulie_pie"), ("uma_thurman", "quincy_quinn"),
    ("viktor_k", "rose_rose"), ("viktor_k", "sammy_sam"), ("wally_world", "terry_terry"),
    ("wally_world", "ursula_u"), ("xena_warrior", "victor_val"), ("xena_warrior", "winnie_pooh"),
    ("yara_gray", "alice123"), ("yara_gray", "bob_smith"), ("zane_zebra", "charlie_brown"),
    ("zane_zebra", "dave01"), ("abby_adams", "eve_89"), ("abby_adams", "frank_the_tank"),
    ("ben_10", "grace_hopper"), ("ben_10", "hank_the_dog"), ("chloe_clark", "ian_fleming"),
    ("chloe_clark", "jane_doe"), ("dan_dare", "karen_miller"), ("dan_dare", "leo_lion"),
    ("ellen_ellen", "mike_tyson"), ("ellen_ellen", "nina_ninja"), ("fred_flint", "oliver_twist"),
    ("fred_flint", "peter_parker"), ("gina_george", "queen_bee"), ("gina_george", "robin_hood"),
    ("hugo_boss", "steve_jobs"), ("hugo_boss", "tina_turner"), ("ivy_ivy", "uma_thurman"),
    ("ivy_ivy", "viktor_k"), ("jack_jill", "wally_world"), ("jack_jill", "xena_warrior"),
    ("ken_kenny", "yara_gray"), ("ken_kenny", "zane_zebra"), ("lisa_love", "abby_adams"),
    ("lisa_love", "ben_10"), ("mark_marky", "chloe_clark"), ("mark_marky", "dan_dare"),
    ("nate_nash", "ellen_ellen"), ("nate_nash", "fred_flint"), ("olivia_olive", "gina_george"),
    ("olivia_olive", "hugo_boss"), ("paulie_pie", "ivy_ivy"), ("paulie_pie", "jack_jill"),
    ("quincy_quinn", "ken_kenny"), ("quincy_quinn", "lisa_love"), ("rose_rose", "mark_marky"),
    ("rose_rose", "nate_nash"), ("sammy_sam", "olivia_olive"), ("sammy_sam", "paulie_pie"),
    ("terry_terry", "quincy_quinn"), ("terry_terry", "rose_rose"), ("ursula_u", "sammy_sam"),
    ("ursula_u", "terry_terry"), ("victor_val", "ursula_u"), ("victor_val", "victor_val"),
    ("winnie_pooh", "winnie_pooh"), ("winnie_pooh", "alice123"), ("bob_smith", "charlie_brown")
]

# Add edges to the graph
G.add_edges_from(edges)

# Calculate in-degrees (number of followers)
in_degrees = G.in_degree()
sorted_in_degrees = sorted(in_degrees, key=lambda x: x[1], reverse=True)

# Get the top 3 most followed users
top_3_most_followed = sorted_in_degrees[:3]

print("Top 3 most followed users:")
for user, followers in top_3_most_followed:
    print(f"{user}: {followers} followers")

# Draw the graph
plt.figure(figsize=(12, 12))
pos = nx.spring_layout(G, seed=42)
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="skyblue", font_size=10, font_color="black", font_weight="bold", edge_color="gray")
plt.title("Social Network Graph")
plt.show()
# Out:
# Top 3 most followed users:
# charlie_brown: 3 followers
# alice123: 2 followers
# bob_smith: 2 followers
