# %%
import numpy as np

def generate_test_scores(mean, std_dev, num_scores):
    # Generate normally distributed scores
    scores = np.random.normal(loc=mean, scale=std_dev, size=num_scores)

    # Clip the scores to be within the range [0, 100]
    scores = np.clip(scores, 0, 100)

    return scores

# Parameters
mean = 70  # Mean of the distribution
std_dev = 15  # Standard deviation of the distribution
num_scores = 100  # Number of test scores to generate

# Generate the test scores
test_scores = generate_test_scores(mean, std_dev, num_scores)

# Print the test scores
print(test_scores)
# Out:
# [ 77.86385988  75.58776005  80.2920805   43.05180269  73.1468481
#   50.79093144  64.46961141  96.95629526  59.06470357  66.09455884
#   99.27601176  67.05456977  80.43181639  59.25828714  36.47230035
#   91.94675007  85.58045981  60.21905516  67.47461632  59.26090577
#   73.39152375  53.78595087  80.34730924  89.43263185  93.38359937
#   58.4254117   85.69947548  49.85990139  49.62618329  77.4860574
#   77.99216201  57.0162262   44.58453722  75.28956302  62.23848307
#   62.47391457  72.59165863  90.70849003  72.2091315   73.67252554
#   89.45912895  70.9675379   84.38192773  93.08712976  70.53755599
#   69.70750459  82.46367747  66.30416949  67.35654298 100.
#   83.52999393  86.39492715  81.19969945  76.66335298  73.53162255
#   77.6611384   74.77932722  71.61249729  87.06965848  78.0734983
#   73.8452939   35.69220371  63.59714732  69.98040151  80.14681078
#   72.11118286  72.40601478  37.93591206  63.49919155  55.86877683
#   87.98370467  63.62245286  79.52823446  63.69168886  88.52993061
#   76.72807569  59.94627464  62.75783442  87.72953939  57.67750724
#  100.          52.54730416  93.83401287  57.62058011  71.40981615
#   56.76815237  58.00682957  59.63695276  90.84056295  69.41710364
#   87.31335128  56.2268471   69.14223265  65.16248582  80.63915073
#   79.21134391  68.10849242  69.46472836  78.59829082 100.        ]

# %%
import numpy as np

def generate_test_scores(mean, std_dev, num_scores):
    # Generate normally distributed scores
    scores = np.random.normal(loc=mean, scale=std_dev, size=num_scores)

    # Clip the scores to be within the range [0, 100]
    scores = np.clip(scores, 0, 100)

    # Round the scores to the nearest integer
    scores = np.round(scores).astype(int)

    return scores

# Parameters
mean = 70  # Mean of the distribution
std_dev = 15  # Standard deviation of the distribution
num_scores = 100  # Number of test scores to generate

# Generate the test scores
test_scores = generate_test_scores(mean, std_dev, num_scores)

# Print the test scores
print(test_scores)
# Out:
# [ 75  59  61  48  96  95 100  68  69  76  82  49 100  83  75  61  53  67
#   77  53  63  86  64  79  55  85  77  82  94  76  38  72  85  44  69  68
#   84  73  71  47  73  71  77  69  78 100  68  73  84  59  78  85  65  60
#   60  59  69  82  36  45  97  55  84  40  90  76  50  67  70  84  73  65
#   72  67  73  57  80  71  66  63  82  75  73  53  64  49  64  60  82  79
#   61  37  92  80  91  78  80  67  81  80]

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_test_scores(mean, std_dev, num_scores):
    # Generate normally distributed scores
    scores = np.random.normal(loc=mean, scale=std_dev, size=num_scores)

    # Clip the scores to be within the range [0, 100]
    scores = np.clip(scores, 0, 100)

    # Round the scores to the nearest integer
    scores = np.round(scores).astype(int)

    return scores

def plot_scores_distribution(scores):
    # Plot a histogram of the scores
    plt.hist(scores, bins=20, edgecolor='black')
    plt.title('Distribution of Test Scores')
    plt.xlabel('Score')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# Parameters
mean = 70  # Mean of the distribution
std_dev = 15  # Standard deviation of the distribution
num_scores = 100  # Number of test scores to generate

# Generate the test scores
test_scores = generate_test_scores(mean, std_dev, num_scores)

# Plot the distribution of the test scores
plot_scores_distribution(test_scores)
