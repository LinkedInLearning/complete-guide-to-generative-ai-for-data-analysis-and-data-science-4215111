# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the data as a dictionary
data = {
    'Date of Sale': [
        '2024-01-15', '2024-03-01', '2024-04-16', '2024-06-01', '2024-07-17',
        '2024-09-01', '2024-10-17', '2024-12-02', '2025-01-17', '2025-03-04',
        '2025-04-19', '2025-06-04', '2025-07-20', '2025-09-04', '2025-10-20',
        '2025-12-05', '2024-02-14', '2024-04-30', '2024-07-01', '2024-09-16',
        '2024-11-01', '2025-01-01', '2025-03-18', '2025-05-03', '2025-07-18',
        '2025-09-02', '2025-11-17', '2025-12-31', '2024-05-15', '2024-08-30'
    ],
    'Sale Price': [
        200000, 204500, 209000, 213500, 218000,
        222500, 227000, 231500, 236000, 240500,
        245000, 249500, 254000, 258500, 263000,
        267500, 207250, 211750, 216250, 220750,
        225250, 229750, 234250, 238750, 243250,
        247750, 252250, 256750, 214750, 219250
    ],
    'Price per Sq.Ft.': [
        150, 153, 156, 159, 162,
        165, 168, 171, 174, 177,
        180, 183, 186, 189, 192,
        195, 159, 162, 165, 168,
        171, 174, 177, 180, 183,
        186, 189, 192, 165, 168
    ]
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Convert 'Date of Sale' to datetime
df['Date of Sale'] = pd.to_datetime(df['Date of Sale'])

# Sort the DataFrame by 'Date of Sale'
df.sort_values(by='Date of Sale', inplace=True)

# Set 'Date of Sale' as the index
df.set_index('Date of Sale', inplace=True)

# Plot the data
plt.figure(figsize=(14, 7))

# Plot Sale Price
plt.plot(df.index, df['Sale Price'], label='Sale Price', color='blue', marker='o')

# Plot Price per Sq.Ft.
plt.plot(df.index, df['Price per Sq.Ft.'], label='Price per Sq.Ft.', color='green', marker='o')

# Set plot title and labels
plt.title('Trends in Sale Price and Price per Sq.Ft.')
plt.xlabel('Date of Sale')
plt.ylabel('Value')

# Add a legend
plt.legend()

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show grid
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the data as a dictionary
data = {
    'Date of Sale': [
        '2024-01-15', '2024-03-01', '2024-04-16', '2024-06-01', '2024-07-17',
        '2024-09-01', '2024-10-17', '2024-12-02', '2025-01-17', '2025-03-04',
        '2025-04-19', '2025-06-04', '2025-07-20', '2025-09-04', '2025-10-20',
        '2025-12-05', '2024-02-14', '2024-04-30', '2024-07-01', '2024-09-16',
        '2024-11-01', '2025-01-01', '2025-03-18', '2025-05-03', '2025-07-18',
        '2025-09-02', '2025-11-17', '2025-12-31', '2024-05-15', '2024-08-30'
    ],
    'Sale Price': [
        200000, 204500, 209000, 213500, 218000,
        222500, 227000, 231500, 236000, 240500,
        245000, 249500, 254000, 258500, 263000,
        267500, 207250, 211750, 216250, 220750,
        225250, 229750, 234250, 238750, 243250,
        247750, 252250, 256750, 214750, 219250
    ],
    'Price per Sq.Ft.': [
        150, 153, 156, 159, 162,
        165, 168, 171, 174, 177,
        180, 183, 186, 189, 192,
        195, 159, 162, 165, 168,
        171, 174, 177, 180, 183,
        186, 189, 192, 165, 168
    ]
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Convert 'Date of Sale' to datetime
df['Date of Sale'] = pd.to_datetime(df['Date of Sale'])

# Sort the DataFrame by 'Date of Sale'
df.sort_values(by='Date of Sale', inplace=True)

# Set 'Date of Sale' as the index
df.set_index('Date of Sale', inplace=True)

# Plot the data for Sale Price
plt.figure(figsize=(14, 7))
plt.plot(df.index, df['Sale Price'], label='Sale Price', color='blue', marker='o')
plt.title('Trends in Sale Price')
plt.xlabel('Date of Sale')
plt.ylabel('Sale Price ($)')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot the data for Price per Sq.Ft.
plt.figure(figsize=(14, 7))
plt.plot(df.index, df['Price per Sq.Ft.'], label='Price per Sq.Ft.', color='green', marker='o')
plt.title('Trends in Price per Sq.Ft.')
plt.xlabel('Date of Sale')
plt.ylabel('Price per Sq.Ft. ($)')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
