# %%
import numpy as np

def generate_test_scores(num_scores, mean=70, std_dev=15, min_score=0, max_score=100):
    """
    Generate a list of normally distributed test scores.

    Parameters:
    - num_scores: The number of test scores to generate.
    - mean: The mean of the normal distribution (default is 70).
    - std_dev: The standard deviation of the normal distribution (default is 15).
    - min_score: The minimum possible score (default is 0).
    - max_score: The maximum possible score (default is 100).

    Returns:
    - A list of test scores.
    """
    # Generate normally distributed scores
    scores = np.random.normal(loc=mean, scale=std_dev, size=num_scores)

    # Clip the scores to be within the specified range
    scores = np.clip(scores, min_score, max_score)

    # Convert the numpy array to a list
    scores_list = scores.tolist()

    return scores_list

# Example usage
if __name__ == "__main__":
    num_scores = 100
    test_scores = generate_test_scores(num_scores)
    print(test_scores)
# Out:
# [62.58386502521918, 72.77054161143636, 73.13213784725242, 72.54101844698107, 79.9435510068938, 90.13670293215655, 77.84245824917214, 89.99912733919957, 77.94413066663466, 84.49099359638598, 74.54983411541427, 94.51086099869335, 53.71959234525406, 54.6273015151331, 71.35719945952546, 67.75438795094298, 66.21629791219647, 74.09367576521733, 76.39697654932391, 100.0, 72.40667415980545, 75.13620333416844, 43.19626029116391, 78.06563699905536, 35.31417703287829, 53.29527656858145, 77.9182183631634, 73.15449725798146, 90.91364254709234, 76.09340783996724, 63.446821246937795, 89.88143037448484, 52.06506926507278, 47.20712357747993, 63.37594287350436, 74.91777484802533, 78.58030819544406, 62.43293895624407, 52.31306490998851, 64.38407210695014, 66.702988076058, 71.41958784462531, 32.744389983253555, 74.73448422006616, 58.01741074875247, 52.05972357418277, 56.225878148539294, 92.61678677125708, 27.194765188878186, 82.37720509423633, 64.81565485302467, 77.44850293267768, 55.64838560019369, 64.
# ...

# %%
import numpy as np

def generate_test_scores(num_scores, mean=70, std_dev=15, min_score=0, max_score=100):
    """
    Generate a list of normally distributed test scores as integers.

    Parameters:
    - num_scores: The number of test scores to generate.
    - mean: The mean of the normal distribution (default is 70).
    - std_dev: The standard deviation of the normal distribution (default is 15).
    - min_score: The minimum possible score (default is 0).
    - max_score: The maximum possible score (default is 100).

    Returns:
    - A list of integer test scores.
    """
    # Generate normally distributed scores
    scores = np.random.normal(loc=mean, scale=std_dev, size=num_scores)

    # Clip the scores to be within the specified range
    scores = np.clip(scores, min_score, max_score)

    # Convert the scores to integers
    scores = scores.astype(int)

    # Convert the numpy array to a list
    scores_list = scores.tolist()

    return scores_list

# Example usage
if __name__ == "__main__":
    num_scores = 100
    test_scores = generate_test_scores(num_scores)
    print(test_scores)
# Out:
# [83, 48, 70, 61, 75, 44, 100, 49, 87, 84, 68, 81, 69, 46, 59, 73, 86, 66, 48, 100, 77, 82, 77, 70, 77, 76, 67, 50, 84, 68, 72, 92, 75, 80, 85, 85, 78, 72, 77, 74, 59, 57, 70, 43, 68, 99, 81, 48, 54, 100, 59, 65, 66, 94, 46, 73, 74, 70, 85, 75, 76, 83, 62, 79, 73, 68, 74, 84, 68, 61, 83, 71, 66, 83, 64, 81, 100, 51, 78, 78, 64, 64, 59, 68, 81, 80, 76, 70, 75, 47, 65, 32, 81, 83, 77, 76, 76, 89, 84, 65]

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_test_scores(num_scores, mean=70, std_dev=15, min_score=0, max_score=100):
    """
    Generate a list of normally distributed test scores as integers.

    Parameters:
    - num_scores: The number of test scores to generate.
    - mean: The mean of the normal distribution (default is 70).
    - std_dev: The standard deviation of the normal distribution (default is 15).
    - min_score: The minimum possible score (default is 0).
    - max_score: The maximum possible score (default is 100).

    Returns:
    - A list of integer test scores.
    """
    # Generate normally distributed scores
    scores = np.random.normal(loc=mean, scale=std_dev, size=num_scores)

    # Clip the scores to be within the specified range
    scores = np.clip(scores, min_score, max_score)

    # Convert the scores to integers
    scores = scores.astype(int)

    # Convert the numpy array to a list
    scores_list = scores.tolist()

    return scores_list

def plot_scores_distribution(scores):
    """
    Plot a histogram of the test scores distribution.

    Parameters:
    - scores: A list of test scores.
    """
    plt.figure(figsize=(10, 6))
    plt.hist(scores, bins=range(0, 101, 5), edgecolor='black', alpha=0.7)
    plt.title('Distribution of Test Scores')
    plt.xlabel('Score')
    plt.ylabel('Frequency')
    plt.xticks(range(0, 101, 5))
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# Example usage
if __name__ == "__main__":
    num_scores = 100
    test_scores = generate_test_scores(num_scores)
    plot_scores_distribution(test_scores)
