# %%
import pandas as pd
import json

# Load the JSON data from the provided file path
file_path = '/mnt/data/products.json'

with open(file_path, 'r') as file:
    data = json.load(file)

# Normalize the JSON data into a flat table
df = pd.json_normalize(data)

# Display the dataframe
import ace_tools as tools; tools.display_dataframe_to_user(name="Products Data", dataframe=df)

df.head()
